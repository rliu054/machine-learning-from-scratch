# %%
# %matplotlib inline
import importlib
import log_reg

importlib.reload(log_reg)

data_arr, label_mat = log_reg.load_data_set()
weights = log_reg.grad_ascent(data_arr, label_mat)
log_reg.plot_best_fit(weights)

# %%
importlib.reload(log_reg)

data_mat, label_mat = log_reg.load_data_set()
weights = log_reg.stoc_grad_ascent(np.array(data_mat), label_mat)
log_reg.plot_best_fit(weights)

# %%
importlib.reload(log_reg)

data_mat, label_mat = log_reg.load_data_set()
weights = log_reg.stoc_grad_ascent_improved(np.array(data_mat), label_mat, 500)
log_reg.plot_best_fit(weights)

# %%
importlib.reload(log_reg)

log_reg.multi_test()
